# %%
import os
import subprocess
import shutil
# Function to convert any audio file to mp3 and save all mp3 files in a new directory, preserving folder structure
def convert_all_to_mp3(directory, output_directory):
    supported_extensions = ('.aac', '.opus', '.m4a', '.wav', '.flac')

    for root, dirs, files in os.walk(directory):
        for file_name in files:
            input_file = os.path.join(root, file_name)

            # Preserve the relative path in the output folder
            relative_path = os.path.relpath(root, directory)
            output_dir_with_structure = os.path.join(output_directory, relative_path)

            # Create the folder structure in the output directory if it doesn't exist
            if not os.path.exists(output_dir_with_structure):
                os.makedirs(output_dir_with_structure)

            # Destination for the converted or copied mp3 file in the new directory
            output_file = os.path.join(output_dir_with_structure, file_name.rsplit('.', 1)[0] + '.mp3')

            # If the file is already an mp3, copy it to the new directory with folder structure
            if file_name.lower().endswith('.mp3'):
                print(f"Copying {file_name} to {output_dir_with_structure}")
                shutil.copy(input_file, output_file)
                continue

            # Check if the file has a supported non-mp3 extension
            if file_name.lower().endswith(supported_extensions):
                # Temporary file for conversion
                temp_output_file = os.path.join(root, file_name.rsplit('.', 1)[0] + '_temp.mp3')

                try:
                    # Construct the ffmpeg command to convert any file to .mp3
                    command = ['ffmpeg', '-i', input_file, '-codec:a', 'libmp3lame', temp_output_file]
                    # Run the command
                    subprocess.run(command, check=True)
                    print(f"Converted {input_file} to MP3")

                    # Move the converted mp3 file to the output directory, preserving folder structure
                    shutil.move(temp_output_file, output_file)
                    print(f"Saved {output_file} to {output_dir_with_structure}")

                except subprocess.CalledProcessError as e:
                    print(f"Error converting {input_file}: {e}")

# Path to the dataset folder
dataset_folder = './data-set/DATASET_AUDIO'

# Path to the output folder for converted mp3 files, preserving folder structure
output_folder = './data-set/DATASET_AUDIO_CONVERTED'

# Convert all supported audio files in the dataset to mp3 and save to the output folder with structure
convert_all_to_mp3(dataset_folder, output_folder)
# Out:
# Converted ./data-set/DATASET_AUDIO\baby shark\Audio 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Audio 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Audio 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Audio 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\audio 9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\audio 9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying Baby shark  (1).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark (1).m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark (1).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying Baby shark (1).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying Baby shark .mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark 9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark 9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark chotu hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark chotu hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark chotu.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark chotu.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da 5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da 5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da 8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da 8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark Da3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark Da3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark da9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark da9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark hum .m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark hum .mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying Baby shark hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark kushi hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark kushi hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark kushi.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark kushi.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark n9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark n9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Baby shark.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Baby shark.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying Baby shark.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying Babyshark hum (1).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Babyshark hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Babyshark hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying Babyshark hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Babyshark.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Babyshark.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\BabyShark14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\BabyShark14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\BabyShark15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\BabyShark15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\BabyShark16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\BabyShark16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\BabyShark17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\BabyShark17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyShark_hum1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyShark_hum1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\babyshark_hum2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\babyshark_hum2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs-1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs-1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs-2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs-2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs-3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs-3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs-4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs-4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs-5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs-5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs-6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs-6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs1.aac to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs2.opus to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs3.aac to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying bs5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Copying bs7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\bs9.aac to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\bs9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 100.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 100.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 109.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 109.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 110.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 110.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 119.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 119.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 120.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 120.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 129.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 129.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 130.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 130.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 147.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 147.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 148.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 148.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 157.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 157.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 158.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 158.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 29.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 29.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 30.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 30.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 39.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 39.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 40.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 40.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 49.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 49.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 50.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 50.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 59.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 59.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 60.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 60.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 69.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 69.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 70.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 70.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 71.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 71.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 72.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 72.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 89.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 89.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 90.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 90.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr 99.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr 99.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lakeside Dr.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lakeside Dr.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Lyrical.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Lyrical.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 2 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 2 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 2 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 2 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 2 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 2 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 3 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 3 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 3 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 3 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 3 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 3 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 4 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 4 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 4 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 4 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 4 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 4 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 5 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 5 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 5 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 5 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\modified 5 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\modified 5 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\New Recording 28.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\New Recording 28.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\New Recording 37.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\New Recording 37.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\Shark hmmm.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\Shark hmmm.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_19.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_19.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_20.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_20.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_21.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_21.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_22.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_22.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_23.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_23.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_24.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_24.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_25.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_25.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\baby shark\upload_9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\baby shark\upload_9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\baby shark
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\audio 9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\audio 9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 103.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 103.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 104.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 104.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 113.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 113.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 114.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 114.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 123.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 123.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 124.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 124.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 133.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 133.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 134.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 134.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 143.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 143.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 144.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 144.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 155.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 155.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 156.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 156.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 23.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 23.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 24.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 24.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 33.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 33.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 34.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 34.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 43.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 43.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 44.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 44.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 53.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 53.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 54.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 54.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 63.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 63.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 64.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 64.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 75.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 75.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 76.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 76.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 84.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 84.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 93.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 93.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Lakeside Dr 94.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Lakeside Dr 94.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\m-1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\m-1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\m-2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\m-2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\m-3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\m-3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\m-4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\m-4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\m-5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\m-5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\m-6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\m-6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Marry had  chotu.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Marry had  chotu.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Marry had a kushi hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb\Marry had a kushi hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\mary had a little lamb
# Converted ./data-set/DATASET_AUDIO\mary had a little lamb\Marry had a kushi.m4a to MP3
# ...
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels 9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels 9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da 17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da 17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels da9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels da9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels hmm.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels hmm.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Copying Wheels hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n12.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n12.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n13.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n13.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n16.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n16.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n17.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n17.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n18.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n18.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels n9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels n9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels on bus.aac to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels on bus.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Copying Wheels on hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus (1).m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus (1).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Copying Wheels on the bus (1).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus .m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus .mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus chotu hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus chotu hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus chotu.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus chotu.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus hum (1).m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus hum (1).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus hum (2).m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus hum (2).mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus hum kushi.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus hum kushi.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus hum.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus hum.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus kushi.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus kushi.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels on the bus.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels on the bus.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Copying Wheels on the bus.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels10.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels10.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels11.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels11.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels14.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels14.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels15.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels15.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\Wheels4.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\Wheels4.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels5.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels5.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels6.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels6.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels7.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels7.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels8.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels8.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels9.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels9.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels_hum1.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels_hum1.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels_hum2.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels_hum2.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus
# Converted ./data-set/DATASET_AUDIO\wheels on the bus\wheels_hum3.m4a to MP3
# Saved ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus\wheels_hum3.mp3 to ./data-set/DATASET_AUDIO_CONVERTED\wheels on the bus

# %%
# Imports
import os
import librosa
import numpy as np
import resampy
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D,Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical

# %%
# Dataset path
dataset_folder = './data-set/DATASET_AUDIO_CONVERTED'

# Extract audio features using MFCC, Chroma, and Mel Spectrogram
def extract_features(file_name):
    audio, sample_rate = librosa.load(file_name, res_type='scipy')  # Load audio file
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=60)  # Increase MFCC coefficients to 60
    mfccs_scaled = np.mean(mfccs.T, axis=0)

    # Extract additional features
    chroma = librosa.feature.chroma_stft(y=audio, sr=sample_rate)
    chroma_scaled = np.mean(chroma.T, axis=0)

    mel = librosa.feature.melspectrogram(y=audio, sr=sample_rate)
    mel_scaled = np.mean(mel.T, axis=0)

    # Concatenate all features
    return np.hstack((mfccs_scaled, chroma_scaled, mel_scaled))

# %%
# Prepare dataset
def prepare_dataset(dataset_folder):
    features = []
    labels = []

    for folder in os.listdir(dataset_folder):
        folder_path = os.path.join(dataset_folder, folder)
        if os.path.isdir(folder_path):  # Check if it's a directory
            for file in os.listdir(folder_path):
                if file.endswith(".mp3"):  # Assuming files are in .mp3 format
                    file_path = os.path.join(folder_path, file)
                    # Extract features and store them with their labels
                    features.append(extract_features(file_path))
                    labels.append(folder)  # Use the folder name as the label

    return np.array(features), np.array(labels)

# %%
# Load the dataset
X, y = prepare_dataset(dataset_folder)

# Encode labels to numerical values
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Split data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Feature Scaling (Normalization)
from sklearn.preprocessing import StandardScaler
import joblib

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Save the scaler
joblib.dump(scaler, "scaler.pkl")
print("Scaler saved as scaler.pkl")

# Support Vector Machine (SVM) Classifier
svm_model = SVC(kernel='linear', random_state=42)  # You can experiment with different kernels like 'rbf'
svm_model.fit(X_train, y_train)

# Evaluate SVM on validation set
y_val_pred_svm = svm_model.predict(X_val)
val_accuracy_svm = accuracy_score(y_val, y_val_pred_svm)
print(f"Validation Accuracy with SVM: {val_accuracy_svm * 100:.2f}%")

# Evaluate SVM on test set
y_test_pred_svm = svm_model.predict(X_test)
test_accuracy_svm = accuracy_score(y_test, y_test_pred_svm)
print(f"Test Accuracy with SVM: {test_accuracy_svm * 100:.2f}%")
# Out:
# Scaler saved as scaler.pkl
# Validation Accuracy with SVM: 36.88%
# Test Accuracy with SVM: 33.52%
